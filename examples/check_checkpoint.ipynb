# %%
import tensorflow as tf

# %%
reader = tf.train.load_checkpoint('./model_dir_tf2_test/')
shape_from_key = reader.get_variable_to_shape_map()
dtype_from_key = reader.get_variable_to_dtype_map()

# %%
print(len(shape_from_key.keys()))
sorted(shape_from_key.keys())
# Out:
# 613
# ['bert_pre_trained_model/bert/embeddings/LayerNorm/beta',
#  'bert_pre_trained_model/bert/embeddings/LayerNorm/beta/Adam',
#  'bert_pre_trained_model/bert/embeddings/LayerNorm/beta/Adam_1',
#  'bert_pre_trained_model/bert/embeddings/LayerNorm/gamma',
#  'bert_pre_trained_model/bert/embeddings/LayerNorm/gamma/Adam',
#  'bert_pre_trained_model/bert/embeddings/LayerNorm/gamma/Adam_1',
#  'bert_pre_trained_model/bert/embeddings/position_embeddings',
#  'bert_pre_trained_model/bert/embeddings/position_embeddings/Adam',
#  'bert_pre_trained_model/bert/embeddings/position_embeddings/Adam_1',
#  'bert_pre_trained_model/bert/embeddings/token_type_embeddings',
#  'bert_pre_trained_model/bert/embeddings/token_type_embeddings/Adam',
#  'bert_pre_trained_model/bert/embeddings/token_type_embeddings/Adam_1',
#  'bert_pre_trained_model/bert/embeddings/word_embeddings',
#  'bert_pre_trained_model/bert/embeddings/word_embeddings/Adam',
# ...

# %%
shape_from_key
# Out:
# {'bert_pre_trained_model/bert/encoder/layer_0/attention/self/value/bias/Adam_1': [768],
#  'bert_pre_trained_model/bert/encoder/layer_4/attention/self/value/kernel/Adam_1': [768,
#   768],
#  'bert_pre_trained_model/bert/embeddings/LayerNorm/beta': [768],
#  'bert_pre_trained_model/bert/encoder/layer_0/attention/self/value/kernel': [768,
#   768],
#  'bert_pre_trained_model/bert/embeddings/LayerNorm/beta/Adam': [768],
#  'bert_pre_trained_model/bert/encoder/layer_6/attention/self/value/bias/Adam': [768],
#  'bert_pre_trained_model/bert/encoder/layer_6/output/dense/kernel': [3072,
#   768],
#  'bert_pre_trained_model/bert/encoder/layer_0/intermediate/dense/kernel/Adam_1': [768,
#   3072],
#  'bert_pre_trained_model/bert/encoder/layer_0/attention/self/key/bias/Adam_1': [768],
#  'bert_pre_trained_model/bert/embeddings/position_embeddings/Adam': [512, 768],
#  'bert_pre_trained_model/bert/encoder/layer_7/attention/output/dense/bias/Adam': [768],
# ...

# %%
dtype_from_key
# Out:
# {'bert_pre_trained_model/bert/encoder/layer_0/attention/self/value/bias/Adam_1': tf.float32,
#  'bert_pre_trained_model/bert/encoder/layer_4/attention/self/value/kernel/Adam_1': tf.float32,
#  'bert_pre_trained_model/bert/embeddings/LayerNorm/beta': tf.float32,
#  'bert_pre_trained_model/bert/encoder/layer_0/attention/self/value/kernel': tf.float32,
#  'bert_pre_trained_model/bert/embeddings/LayerNorm/beta/Adam': tf.float32,
#  'bert_pre_trained_model/bert/encoder/layer_6/attention/self/value/bias/Adam': tf.float32,
#  'bert_pre_trained_model/bert/encoder/layer_6/output/dense/kernel': tf.float32,
#  'bert_pre_trained_model/bert/encoder/layer_0/intermediate/dense/kernel/Adam_1': tf.float32,
#  'bert_pre_trained_model/bert/encoder/layer_0/attention/self/key/bias/Adam_1': tf.float32,
#  'bert_pre_trained_model/bert/embeddings/position_embeddings/Adam': tf.float32,
#  'bert_pre_trained_model/bert/encoder/layer_7/attention/output/dense/bias/Adam': tf.float32,
# ...

# %%
dir(reader)
# Out:
# ['CheckpointReader_GetTensor',
#  '_GetVariableToDataTypeMap',
#  '_HasTensor',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'debug_string',
#  'get_tensor',
#  'get_variable_to_dtype_map',
#  'get_variable_to_shape_map',
#  'has_tensor']

# %%
help(reader)
# Out:
# Help on CheckpointReader in module tensorflow.python.util._pywrap_checkpoint_reader object:
#
# class CheckpointReader(pybind11_builtins.pybind11_object)
#  |  Method resolution order:
#  |      CheckpointReader
#  |      pybind11_builtins.pybind11_object
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(...)
#  |      __init__(self: tensorflow.python.util._pywrap_checkpoint_reader.CheckpointReader, arg0: str) -> None
#  |
#  |  debug_string(...)
#  |      debug_string(self: tensorflow.python.util._pywrap_checkpoint_reader.CheckpointReader) -> bytes
#  |
#  |  get_tensor(self, tensor_str)
#  |      Get the tensor from the Checkpoint object.
#  |
#  |  get_variable_to_dtype_map(self)
#  |
#  |  get_variable_to_shape_map(...)
#  |      get_variable_to_shape_map(self: tensorflow.python.util._pywrap_checkpoint_reader.CheckpointReader) -> Dict[str, tensorflow::TensorShape]
#  |
#  |  has_tensor(self, tensor_str)
#  |
# ...

# %%
# 检查预训练模型
pretrain_reader = tf.train.load_checkpoint('D:/code/py_nlp_classify/model/bert/google-bert-base-zh/bert_model.ckpt')
pretrain_shape_from_key = pretrain_reader.get_variable_to_shape_map()
pretrain_dtype_from_key = pretrain_reader.get_variable_to_dtype_map()

# %%
print(len(pretrain_shape_from_key.keys()))
sorted(pretrain_dtype_from_key.keys())
# Out:
# 206
# ['bert/embeddings/LayerNorm/beta',
#  'bert/embeddings/LayerNorm/gamma',
#  'bert/embeddings/position_embeddings',
#  'bert/embeddings/token_type_embeddings',
#  'bert/embeddings/word_embeddings',
#  'bert/encoder/layer_0/attention/output/LayerNorm/beta',
#  'bert/encoder/layer_0/attention/output/LayerNorm/gamma',
#  'bert/encoder/layer_0/attention/output/dense/bias',
#  'bert/encoder/layer_0/attention/output/dense/kernel',
#  'bert/encoder/layer_0/attention/self/key/bias',
#  'bert/encoder/layer_0/attention/self/key/kernel',
#  'bert/encoder/layer_0/attention/self/query/bias',
#  'bert/encoder/layer_0/attention/self/query/kernel',
#  'bert/encoder/layer_0/attention/self/value/bias',
#  'bert/encoder/layer_0/attention/self/value/kernel',
#  'bert/encoder/layer_0/intermediate/dense/bias',
#  'bert/encoder/layer_0/intermediate/dense/kernel',
#  'bert/encoder/layer_0/output/LayerNorm/beta',
#  'bert/encoder/layer_0/output/LayerNorm/gamma',
# ...

# %%
tf.train.list_variables('D:/code/py_nlp_classify/model/bert/google-bert-base-zh/bert_model.ckpt')
# Out:
# [('bert/embeddings/LayerNorm/beta', [768]),
#  ('bert/embeddings/LayerNorm/gamma', [768]),
#  ('bert/embeddings/position_embeddings', [512, 768]),
#  ('bert/embeddings/token_type_embeddings', [2, 768]),
#  ('bert/embeddings/word_embeddings', [21128, 768]),
#  ('bert/encoder/layer_0/attention/output/LayerNorm/beta', [768]),
#  ('bert/encoder/layer_0/attention/output/LayerNorm/gamma', [768]),
#  ('bert/encoder/layer_0/attention/output/dense/bias', [768]),
#  ('bert/encoder/layer_0/attention/output/dense/kernel', [768, 768]),
#  ('bert/encoder/layer_0/attention/self/key/bias', [768]),
#  ('bert/encoder/layer_0/attention/self/key/kernel', [768, 768]),
#  ('bert/encoder/layer_0/attention/self/query/bias', [768]),
#  ('bert/encoder/layer_0/attention/self/query/kernel', [768, 768]),
#  ('bert/encoder/layer_0/attention/self/value/bias', [768]),
#  ('bert/encoder/layer_0/attention/self/value/kernel', [768, 768]),
#  ('bert/encoder/layer_0/intermediate/dense/bias', [3072]),
# ...

# %%
tf.train.list_variables("./model_dir_tf2_test/")
# Out:
# [('bert_pre_trained_model/bert/embeddings/LayerNorm/beta', [768]),
#  ('bert_pre_trained_model/bert/embeddings/LayerNorm/beta/Adam', [768]),
#  ('bert_pre_trained_model/bert/embeddings/LayerNorm/beta/Adam_1', [768]),
#  ('bert_pre_trained_model/bert/embeddings/LayerNorm/gamma', [768]),
#  ('bert_pre_trained_model/bert/embeddings/LayerNorm/gamma/Adam', [768]),
#  ('bert_pre_trained_model/bert/embeddings/LayerNorm/gamma/Adam_1', [768]),
#  ('bert_pre_trained_model/bert/embeddings/position_embeddings', [512, 768]),
#  ('bert_pre_trained_model/bert/embeddings/position_embeddings/Adam',
#   [512, 768]),
#  ('bert_pre_trained_model/bert/embeddings/position_embeddings/Adam_1',
#   [512, 768]),
#  ('bert_pre_trained_model/bert/embeddings/token_type_embeddings', [2, 768]),
#  ('bert_pre_trained_model/bert/embeddings/token_type_embeddings/Adam',
#   [2, 768]),
#  ('bert_pre_trained_model/bert/embeddings/token_type_embeddings/Adam_1',
#   [2, 768]),
# ...
